# %% [markdown]
# <a href="https://colab.research.google.com/github/manikur/R-programming/blob/main/Project_2_adult_income_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']= '/content/drive/My Drive/Kaggle'

# %%
# %cd /content/drive/My Drive/Kaggle
# Out:
# /content/drive/My Drive/Kaggle

# %%
# !kaggle datasets download -d wenruliu/adult-income-dataset
# Out:
# adult-income-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip \*.zip && rm *.zip
# Out:
# Archive:  adult-income-dataset.zip
# replace adult.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: adult.csv

# %%
data=pd.read_csv('adult.csv')
data
# Out:
#        age     workclass  fnlwgt  ... hours-per-week  native-country income
# 0       25       Private  226802  ...             40   United-States  <=50K
# 1       38       Private   89814  ...             50   United-States  <=50K
# 2       28     Local-gov  336951  ...             40   United-States   >50K
# 3       44       Private  160323  ...             40   United-States   >50K
# 4       18             ?  103497  ...             30   United-States  <=50K
# ...    ...           ...     ...  ...            ...             ...    ...
# 48837   27       Private  257302  ...             38   United-States  <=50K
# 48838   40       Private  154374  ...             40   United-States   >50K
# 48839   58       Private  151910  ...             40   United-States  <=50K
# 48840   22       Private  201490  ...             20   United-States  <=50K
# 48841   52  Self-emp-inc  287927  ...             40   United-States   >50K
#
# [48842 rows x 15 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Display top 10 rows of the Dataset

# %%
data.head()
# Out:
#    age  workclass  fnlwgt  ... hours-per-week  native-country income
# 0   25    Private  226802  ...             40   United-States  <=50K
# 1   38    Private   89814  ...             50   United-States  <=50K
# 2   28  Local-gov  336951  ...             40   United-States   >50K
# 3   44    Private  160323  ...             40   United-States   >50K
# 4   18          ?  103497  ...             30   United-States  <=50K
#
# [5 rows x 15 columns]

# %%
data.tail()
# Out:
#        age     workclass  fnlwgt  ... hours-per-week  native-country income
# 48837   27       Private  257302  ...             38   United-States  <=50K
# 48838   40       Private  154374  ...             40   United-States   >50K
# 48839   58       Private  151910  ...             40   United-States  <=50K
# 48840   22       Private  201490  ...             20   United-States  <=50K
# 48841   52  Self-emp-inc  287927  ...             40   United-States   >50K
#
# [5 rows x 15 columns]

# %% [markdown]
# Find the shape of dataset(Number of rows and Number of columns)

# %%
data.shape
# Out:
# (48842, 15)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 48842
# Number of Columns 15

# %% [markdown]
# Getting information about dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# Fetch Random Samples from the data set(50%)

# %%
data.sample(frac=0.50)
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country income
# 21845   46           Private  191357  ...             40   United-States  <=50K
# 30341   34           Private   46144  ...             40   United-States  <=50K
# 18885   18           Private   80616  ...             27   United-States  <=50K
# 37077   30           Private  302438  ...             40   United-States  <=50K
# 39143   37  Self-emp-not-inc  205359  ...             15   United-States  <=50K
# ...    ...               ...     ...  ...            ...             ...    ...
# 2125    22           Private  155913  ...             18   United-States  <=50K
# 47792   31           Private  298871  ...             40           China  <=50K
# 22312   61      Self-emp-inc  227232  ...             30   United-States  <=50K
# 6350    28           Private  289991  ...             40   United-States   >50K
# 9271    52           Private   94448  ...             40   United-States  <=50K
#
# ...

# %%
data.sample(frac=0.50,random_state=100)
# Out:
#        age  workclass  fnlwgt  ... hours-per-week  native-country income
# 12393   37    Private  110331  ...             60   United-States   >50K
# 48701   23    Private   45834  ...             50   United-States  <=50K
# 17918   28    Private   89718  ...             48   United-States  <=50K
# 11352   30    Private  351770  ...             38   United-States  <=50K
# 36198   31    Private  164190  ...             40   United-States  <=50K
# ...    ...        ...     ...  ...            ...             ...    ...
# 48573   41    Private  318046  ...             48   United-States   >50K
# 47252   41  Local-gov   33658  ...             45   United-States   >50K
# 33142   69    Private  312653  ...             25   United-States  <=50K
# 2965    21          ?  334593  ...             40   United-States  <=50K
# 32089   34    Private  186269  ...             40   United-States  <=50K
#
# [24421 rows x 15 columns]

# %%
data1=data.sample(frac=0.50,random_state=100)
data1
# Out:
#        age  workclass  fnlwgt  ... hours-per-week  native-country income
# 12393   37    Private  110331  ...             60   United-States   >50K
# 48701   23    Private   45834  ...             50   United-States  <=50K
# 17918   28    Private   89718  ...             48   United-States  <=50K
# 11352   30    Private  351770  ...             38   United-States  <=50K
# 36198   31    Private  164190  ...             40   United-States  <=50K
# ...    ...        ...     ...  ...            ...             ...    ...
# 48573   41    Private  318046  ...             48   United-States   >50K
# 47252   41  Local-gov   33658  ...             45   United-States   >50K
# 33142   69    Private  312653  ...             25   United-States  <=50K
# 2965    21          ?  334593  ...             40   United-States  <=50K
# 32089   34    Private  186269  ...             40   United-States  <=50K
#
# [24421 rows x 15 columns]

# %% [markdown]
# Check null values in the datasets.

# %%
data.isnull()
# Out:
#          age  workclass  fnlwgt  ...  hours-per-week  native-country  income
# 0      False      False   False  ...           False           False   False
# 1      False      False   False  ...           False           False   False
# 2      False      False   False  ...           False           False   False
# 3      False      False   False  ...           False           False   False
# 4      False      False   False  ...           False           False   False
# ...      ...        ...     ...  ...             ...             ...     ...
# 48837  False      False   False  ...           False           False   False
# 48838  False      False   False  ...           False           False   False
# 48839  False      False   False  ...           False           False   False
# 48840  False      False   False  ...           False           False   False
# 48841  False      False   False  ...           False           False   False
#
# [48842 rows x 15 columns]

# %%
data.isnull().sum()  # 0 means do not have missing value
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.isnull().sum(axis=1)  #axis=1 means do not have missing value column
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sns.heatmap(data.isnull())

# %% [markdown]
# Perform data cleaning[Replace'?' with NaN

# %%
data.tail(20)
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country income
# 48822   41                 ?  202822  ...             32   United-States  <=50K
# 48823   72                 ?  129912  ...             25   United-States  <=50K
# 48824   45         Local-gov  119199  ...             48   United-States  <=50K
# 48825   31           Private  199655  ...             30   United-States  <=50K
# 48826   39         Local-gov  111499  ...             20   United-States   >50K
# 48827   37           Private  198216  ...             40   United-States  <=50K
# 48828   43           Private  260761  ...             40          Mexico  <=50K
# 48829   65  Self-emp-not-inc   99359  ...             60   United-States  <=50K
# 48830   43         State-gov  255835  ...             40   United-States  <=50K
# 48831   43  Self-emp-not-inc   27242  ...             50   United-States  <=50K
# 48832   32           Private   34066  ...             40   United-States  <=50K
# ...

# %% [markdown]
# How many column have ? mark?

# %%
data.isin(['?']).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %% [markdown]
# ? marks contain workclass,occupation,native country Replace ?

# %%
import numpy as np

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['workclass'].replace('?',np.nan)
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 4                 NaN
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 48842, dtype: object

# %%
data['workclass']=data['workclass'].replace('?',np.nan)
data['occupation']=data['occupation'].replace('?',np.nan)
data['native-country']=data['native-country'].replace('?',np.nan)

# %%
data.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sns.heatmap(data.isnull())

# %% [markdown]
# Drop all the missing values

# %%
per_missing=data.isnull().sum()*100/len(data)
per_missing
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
data.dropna(how='any',inplace=True)
data.shape
# Out:
# (45222, 15)

# %% [markdown]
# Check for duplicate data and drop them

# %%
dup=data.duplicated().any()
print("Are there any duplicated values in data",dup)
# Out:
# Are there any duplicated values in data True

# %%
data=data.drop_duplicates()
data.shape
# Out:
# (45175, 15)

# %% [markdown]
# Get overall statistics about the data frame

# %%
data.describe()
# Out:
#                 age        fnlwgt  ...  capital-loss  hours-per-week
# count  45175.000000  4.517500e+04  ...  45175.000000    45175.000000
# mean      38.556170  1.897388e+05  ...     88.687593       40.942512
# std       13.215349  1.056524e+05  ...    405.156611       12.007730
# min       17.000000  1.349200e+04  ...      0.000000        1.000000
# 25%       28.000000  1.173925e+05  ...      0.000000       40.000000
# 50%       37.000000  1.783120e+05  ...      0.000000       40.000000
# 75%       47.000000  2.379030e+05  ...      0.000000       45.000000
# max       90.000000  1.490400e+06  ...   4356.000000       99.000000
#
# [8 rows x 6 columns]
