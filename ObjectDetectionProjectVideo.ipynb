# %% [markdown]
# <a href="https://colab.research.google.com/github/manikur/Python-Programming/blob/main/ObjectDetectionProjectVideo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.9/871.9 kB 27.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8x')

results = model.predict('/content/challenge-1075_2.mp4',save=True)
print(results[0])
print('=====================================')
for box in results[0].boxes:
    print(box)
# Out:
# ...
# 100%|██████████| 131M/131M [00:03<00:00, 37.4MB/s]
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/91) /content/challenge-1075_2.mp4: 384x640 20 persons, 1 tv, 104.7ms
# video 1/1 (frame 2/91) /content/challenge-1075_2.mp4: 384x640 20 persons, 1 tv, 53.7ms
# video 1/1 (frame 3/91) /content/challenge-1075_2.mp4: 384x640 20 persons, 1 tv, 53.7ms
# video 1/1 (frame 4/91) /content/challenge-1075_2.mp4: 384x640 20 persons, 1 tv, 53.8ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict/challenge-1075_2.avi"} -vcodec libx264 {"output.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
#Other method to see file
#from google.colab import files
#files.download('/content/runs/detect/predict/challenge-1075_2.avi')
